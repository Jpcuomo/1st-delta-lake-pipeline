# %% [markdown]
# ## **Esta notebook es para pruebas de código**

# %%
from pathlib import Path

# %%
base_dir = Path(__file__).resolve().parent.parent

#ruta = Path(base_dir)
base_dir.exists()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 base_dir = Path(__file__).resolve().parent.parent
#       3 #ruta = Path(base_dir)
#       4 base_dir.exists()
#
# NameError: name '__file__' is not defined

# %%
def saludar(nombre):
    return f"Hola {nombre}!"

# mi_funcion = saludar
# print(mi_funcion('Ana'))

def saludar_y_felicitar(fcion, nombre):
    resultado = fcion(nombre)
    return f'{resultado.title()} Excelente trabajo!!!'

funcion_decorada = saludar_y_felicitar(saludar, 'juan')
funcion_decorada
# Out:
# 'Hola Juan! Excelente trabajo!!!'

# %%
@saludar_y_felicitar
def saludar(nombre):
    return f"Hola {nombre}!"

saludar('juan')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 @saludar_y_felicitar
#       2 def saludar(nombre):
#       3     return f"Hola {nombre}!"
#       5 saludar('juan')
#
# TypeError: saludar_y_felicitar() missing 1 required positional argument: 'nombre'

# %%
# Paso 1: Función dentro de función
def conversacion():
    def decir_hola():
        return "Hola"
    
    def decir_adios():
        return "Adiós"
    
    print(decir_hola())
    print(decir_adios())

conversacion()
# Out:
# Hola
# Adiós

# %%
def crear_procesador(tipo:str):
    def mayusculas(texto:str) -> str:
        return texto.upper()
    
    def minusculas(texto:str)-> str:
        return texto.lower()
    
    if tipo == 'mayuscula':
        return mayusculas
    else:
        return minusculas
    
texto = crear_procesador('mayuscula')('hola')
print(texto)
# Out:
# HOLA

# %%
from src.load.delta_writer import leer_delta_lake
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from src.load.delta_writer import leer_delta_lake
#
# File ~\Desktop\delta_lake_bucket\src\load\__init__.py:1
# ----> 1 from .delta_writer import leer_delta_lake, leer_extraccion_reciente, save_data_as_delta, save_new_data_as_delta
#       3 __all__ = [
#       4     'leer_delta_lake',
#       5     'leer_extraccion_reciente',
#       6     'save_data_as_delta',
#       7     'save_new_data_as_delta'
#       8 ]
#
# File ~\Desktop\delta_lake_bucket\src\load\delta_writer.py:7
#       5 from deltalake import write_deltalake, DeltaTable
#       6 from deltalake.exceptions import TableNotFoundError
# ----> 7 from utils.config_utils import obtener_archivo_incremental
#      10 def leer_delta_lake(path:str) -> pd.DataFrame|None:
#      11     '''
#      12     Lee el archivo Delta Lake ubicado en la ruta del parámetro y lo
#      13     transforma en un DataFrame de Pandas.
#    (...)     20         DataFrame de Pandas si encuentra el path, sino None
#      21     '''
#
# ModuleNotFoundError: No module named 'utils'
